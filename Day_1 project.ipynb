# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagadish-985/AI-ML-Workshop/blob/main/Day_1%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
nigga="tvmarketing.csv"

# %%
advertising=pd.read_csv(nigga)
#Now checking the structure of advertising data

# %%
advertising.head()
# Displaying first 5 rows
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
advertising.tail()
#Displaying last five column
# Out:
#         TV  Sales
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4

# %%
import matplotlib as mp

# %%
import numpy as np

# %%
import sklearn as sk

# %%
advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='TV',y='Sales',data=advertising)
plt.title("TV vs Sales")
plt.xlabel("TV")
plt.ylabel("Sales")
plt.show()
